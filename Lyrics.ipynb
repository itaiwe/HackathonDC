# %% [markdown]
# <a href="https://colab.research.google.com/github/itaiwe/HackathonDC/blob/main/Lyrics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tok = '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'
# !git clone https://{tok}@github.com/Shalevzzz/hw-deep-learning.git
# Out:
# Cloning into 'hw-deep-learning'...
# remote: Enumerating objects: 676, done.
# remote: Counting objects: 100% (676/676), done.
# remote: Compressing objects: 100% (660/660), done.
# remote: Total 676 (delta 17), reused 669 (delta 10), pack-reused 0
# Receiving objects: 100% (676/676), 7.36 MiB | 11.48 MiB/s, done.
# Resolving deltas: 100% (17/17), done.

# %%
# !pip install pretty_midi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.6 MB 4.8 MB/s
# ...
#      |████████████████████████████████| 51 kB 5.7 MB/s
# ...
#   Created wheel for pretty-midi: filename=pretty_midi-0.2.9-py3-none-any.whl size=5591954 sha256=03310ea89a6a4068a1635f091e87760f66f364b6cd09a484ad3086a594da35aa
#   Stored in directory: /root/.cache/pip/wheels/2a/5a/e3/30eeb9a99350f3f7e21258fcb132743eef1a4f49b3505e76b6
# Successfully built pretty-midi
# ...

# %%
import pretty_midi

# %%
midi_data = pretty_midi.PrettyMIDI('/content/hw-deep-learning/assignment 3/midi_files/1910_Fruitgum_Company_-_Simon_Says.mid')

# %%
midi_data.get_piano_roll
# Out:
# <bound method PrettyMIDI.get_piano_roll of <pretty_midi.pretty_midi.PrettyMIDI object at 0x7f11e2f17be0>>

# %%
midi_data.instruments[0].notes
# Out:
# [Note(start=3.999996, end=4.342588, pitch=61, velocity=127),
#  Note(start=3.999996, end=4.344903, pitch=73, velocity=127),
#  Note(start=3.999996, end=4.418977, pitch=85, velocity=127),
#  Note(start=4.444440, end=4.601847, pitch=74, velocity=127),
#  Note(start=4.444440, end=4.608792, pitch=62, velocity=127),
#  Note(start=4.444440, end=4.671292, pitch=86, velocity=127),
#  Note(start=4.666662, end=4.902773, pitch=66, velocity=127),
#  Note(start=4.666662, end=4.928236, pitch=78, velocity=127),
#  Note(start=4.666662, end=5.023143, pitch=90, velocity=127),
#  Note(start=5.111106, end=5.372680, pitch=76, velocity=127),
#  Note(start=5.111106, end=5.407402, pitch=64, velocity=127),
#  Note(start=5.111106, end=5.453698, pitch=88, velocity=127),
#  Note(start=5.555550, end=5.604161, pitch=68, velocity=127),
#  Note(start=5.555550, end=5.606476, pitch=64, velocity=127),
#  Note(start=5.555550, end=5.606476, pitch=71, velocity=127),
# ...

# %%
print(midi_data.notes)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-4a1f0c56877d> in <module>
# ----> 1 print(midi_data.notes)
#
# AttributeError: 'PrettyMIDI' object has no attribute 'notes'
